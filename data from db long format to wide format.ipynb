# %%
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine , inspect

# %%
user = "postgres"
password = "mnbvcxz1234567"
host = "3.111.61.248" # "3.109.41.47"
port = 5432
database = "de_db"
 
conn = f"postgresql://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(conn)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@3.111.61.248:5432/de_db)

# %%
inspector = inspect(engine)
table_names = inspector.get_table_names()

# %%
table_names
# Out:
# ['spatial_ref_sys',
#  'indicatr',
#  'city_poi',
#  'city',
#  'brand_nm_104_competitors',
#  'district',
#  'district_poi',
#  'state',
#  'property_data_cs',
#  'city_cs_avgcount',
#  'village',
#  'd_date',
#  'village_poi',
#  'hexgrid08_poi',
#  'hexgrid08_footfall',
#  'locality',
#  'property_data',
#  'hexgrid08_cs',
#  'locality_cs',
#  'city_data',
#  'property_footfall',
#  'locality_bom',
#  'locality_geo_cod',
#  'poi',
#  'locality_data',
#  'brand_com',
#  'property',
#  'hexgrid08',
#  'hexgrid08_data']

# %%
df = pd.DataFrame()  # Initialize an empty DataFrame to hold the final result
indicator = ['building_density',"average_monthly_residential_rental_price"]

for i in indicator:
    query = f"SELECT hexid08, t_name, is_tc, val AS {i} FROM public.hexgrid08_data WHERE indicatr = '{i}' AND t_name = 'Amritsar'"
    result = engine.execute(query)
    rows = result.fetchall()
    
    if len(rows) > 0:  # If there are results for this indicator
        column_names = result.keys()
        temp_df = pd.DataFrame(rows, columns=column_names)
        
        # Dropping duplicate columns if they exist in the new DataFrame
        columns_to_drop = [col for col in temp_df.columns if col in df.columns]
        temp_df = temp_df.drop(columns=columns_to_drop, errors='ignore')
        
        # Concatenating the new DataFrame to the existing master DataFrame
        df = pd.concat([df, temp_df], axis=1)

# Now df contains the merged DataFrame without duplicate columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 6
#       4 for i in indicator:
#       5     query = f"SELECT hexid08, t_name, is_tc, val AS {i} FROM public.hexgrid08_data WHERE indicatr = '{i}' AND t_name ='Amritsar'"
# ----> 6     result = engine.execute(query)
#       7     rows = result.fetchall()
#       9     if len(rows) > 0:  # If there are results for this indicator
#
# NameError: name 'engine' is not defined

# %%
df.to_csv(r'D:\Sociometrik\rent prediction\raw files\amritsar_raw\amritsar_building density.csv')

# %%
buffer_data=pd.read_csv(r"C:\Users\chemi\Downloads\starbucks_h8_mapped.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 buffer_data=pd.read_csv(r"D:\Sociometrik\rent prediction\raw files\amritsar_raw\amritsar_building_density.csv")
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# ...

# %%
buffer_data=buffer_data.merge(df,how="left", on=["hexid08",'t_name','is_tc'])

# %%
buffer_data=buffer_data.drop(columns=["lat",'lon','hexid08','is_tc','t_name'])

# %%
buffer_data.to_csv(r"C:\Users\chemi\Desktop\enviroments\myml\1-Notebooks_python\All Scripts\extract datafrom the data base\output_csv\starbucks\all_data_on_grid_level.csv")

# %%
df=pd.read_csv(r"C:\Users\chemi\Desktop\enviroments\myml\1-Notebooks_python\All Scripts\extract datafrom the data base\output_csv\starbucks\all_data_on_grid_level.csv")

# %%
df=df.groupby(['name',"buff_id"]).agg({'average_monthly_residential_rental_price': 'mean','building_density': 'mean',
    'green_space_density': 'mean',
    'road_length': 'sum',
    'transportation_hubs': 'sum',
    'daily_avg_footfall': 'mean',
    'weekly_avg_footfall': 'mean',
    'consumer_digital_expenditure': 'sum',
    'total_digital_consumers': 'sum',
    'elderly_population': 'sum',
    'female_population': 'sum',
    'female_population_15_to_49years': 'sum',
    'kids_population': 'sum',
    'male_population': 'sum',
    'population': 'sum',
    'population_density': 'mean',
    'youth_population': 'sum',
    'average_monthly_commercial_rental_price': 'mean',
    'auto_dealership': 'sum',
    'auto_service_maintenance': 'sum',
    'motorcycle_dealership': 'sum',
    'truck_dealership': 'sum',
    'business_facility': 'sum',
    'government_office': 'sum',
    'post_office': 'sum',
    'book_store': 'sum',
    'higher_education': 'sum',
    'library': 'sum',
    'school': 'sum',
    'training_centre_institute': 'sum',
    'amusement_park': 'sum',
    'bowling_centre': 'sum',
    'casino': 'sum',
    'cinema': 'sum',
    'golf_course': 'sum',
    'golf_practice_range': 'sum',
    'ice_skating_rink': 'sum',
    'museum': 'sum',
    'nightlife': 'sum',
    'park_recreation_area': 'sum',
    'performing_arts': 'sum',
    'sports_centre': 'sum',
    'atm': 'sum',
    'bank': 'sum',
    'hospital': 'sum',
    'medical_service': 'sum',
    'pharmacy': 'sum',
    'industrial_zone': 'sum',
    'police_station': 'sum',
    'bar_or_pub': 'sum',
    'coffee_shop': 'sum',
    'restaurant': 'sum',
    'clothing_store': 'sum',
    'consumer_electronics_store': 'sum',
    'convenience_store': 'sum',
    'department_store': 'sum',
    'grocery_store': 'sum',
    'home_improvement_hardware_store': 'sum',
    'home_specialty_store': 'sum',
    'office_supply_services_store': 'sum',
    'petrol_gasoline_station': 'sum',
    'shopping': 'sum',
    'sporting_goods_store': 'sum',
    'airport': 'sum',
    'bus_station': 'sum',
    'train_station': 'sum',
    'transportation_service': 'sum',
    'hotel': 'sum',
    'premium_hotels': 'sum',
    'jewellery_store': 'sum',
    })

# %%
df=df.reset_index().sort_values("buff_id")

# %%
df
# Out:
#                                          name   buff_id  \
# 35                     starbucks coffee house  buff0001
# 12           starbucks - church street (s036)  buff0002
# 0                       indiranagar starbucks  buff0003
# 19                           starbucks coffee  buff0004
# 20                           starbucks coffee  buff0005
# 39               starbucks vittal mallya road  buff0006
# 21                           starbucks coffee  buff0007
# 1                                   starbucks  buff0008
# 22                           starbucks coffee  buff0009
# 23                           starbucks coffee  buff0010
# 2                                   starbucks  buff0011
# 3                                   starbucks  buff0012
# 24                           starbucks coffee  buff0013
# 41                      tata starbucks coffee  buff0014
# 25                           starbucks coffee  buff0015
# 26                           starbucks coffee  buff0016
# ...

# %%
df
# Out:
#                                          name   buff_id  \
# 35                     starbucks coffee house  buff0001
# 12           starbucks - church street (s036)  buff0002
# 0                       indiranagar starbucks  buff0003
# 19                           starbucks coffee  buff0004
# 20                           starbucks coffee  buff0005
# 39               starbucks vittal mallya road  buff0006
# 21                           starbucks coffee  buff0007
# 1                                   starbucks  buff0008
# 22                           starbucks coffee  buff0009
# 23                           starbucks coffee  buff0010
# 2                                   starbucks  buff0011
# 3                                   starbucks  buff0012
# 24                           starbucks coffee  buff0013
# 41                      tata starbucks coffee  buff0014
# 25                           starbucks coffee  buff0015
# 26                           starbucks coffee  buff0016
# ...

# %%
df.to_csv(r"C:\Users\chemi\Desktop\enviroments\myml\1-Notebooks_python\All Scripts\extract datafrom the data base\output_csv\starbucks\all_data_on_buffer_level.csv")
